# %%
# !pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in /home/lse01/.local/lib/python3.10/site-packages (8.4.34)
# Requirement already satisfied: numpy>=1.23.0 in /home/lse01/.local/lib/python3.10/site-packages (from ultralytics) (2.2.6)
# Requirement already satisfied: matplotlib>=3.3.0 in /home/lse01/.local/lib/python3.10/site-packages (from ultralytics) (3.10.8)
# Requirement already satisfied: opencv-python>=4.6.0 in /home/lse01/.local/lib/python3.10/site-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in /home/lse01/anaconda3/envs/yolo_env/lib/python3.10/site-packages (from ultralytics) (12.2.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /home/lse01/anaconda3/envs/yolo_env/lib/python3.10/site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /home/lse01/anaconda3/envs/yolo_env/lib/python3.10/site-packages (from ultralytics) (2.33.1)
# Requirement already satisfied: scipy>=1.4.1 in /home/lse01/.local/lib/python3.10/site-packages (from ultralytics) (1.15.3)
# Requirement already satisfied: torch>=1.8.0 in /home/lse01/.local/lib/python3.10/site-packages (from ultralytics) (2.11.0)
# Requirement already satisfied: torchvision>=0.9.0 in /home/lse01/.local/lib/python3.10/site-packages (from ultralytics) (0.26.0)
# Requirement already satisfied: psutil>=5.8.0 in /home/lse01/.local/lib/python3.10/site-packages (from ultralytics) (7.2.2)
# Requirement already satisfied: polars>=0.20.0 in /home/lse01/.local/lib/python3.10/site-packages (from ultralytics) (1.39.3)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in /home/lse01/.local/lib/python3.10/site-packages (from ultralytics) (2.0.18)
# Requirement already satisfied: contourpy>=1.0.1 in /home/lse01/.local/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/lse01/.local/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/lse01/.local/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/lse01/.local/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /home/lse01/.local/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (26.0)
# Requirement already satisfied: pyparsing>=3 in /home/lse01/.local/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/lse01/anaconda3/envs/yolo_env/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.39.3 in /home/lse01/.local/lib/python3.10/site-packages (from polars>=0.20.0->ultralytics) (1.39.3)
# Requirement already satisfied: six>=1.5 in /home/lse01/anaconda3/envs/yolo_env/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/lse01/anaconda3/envs/yolo_env/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/lse01/anaconda3/envs/yolo_env/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /home/lse01/anaconda3/envs/yolo_env/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in /home/lse01/anaconda3/envs/yolo_env/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (2026.2.25)
# Requirement already satisfied: filelock in /home/lse01/.local/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/lse01/.local/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools<82 in /home/lse01/anaconda3/envs/yolo_env/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/lse01/.local/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/lse01/.local/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /home/lse01/.local/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/lse01/.local/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (2026.3.0)
# Requirement already satisfied: cuda-toolkit==13.0.2 in /home/lse01/.local/lib/python3.10/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.8.0->ultralytics) (13.0.2)
# Requirement already satisfied: cuda-bindings<14,>=13.0.3 in /home/lse01/.local/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (13.2.0)
# Requirement already satisfied: nvidia-cudnn-cu13==9.19.0.56 in /home/lse01/.local/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu13==0.8.0 in /home/lse01/.local/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (0.8.0)
# Requirement already satisfied: nvidia-nccl-cu13==2.28.9 in /home/lse01/.local/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu13==3.4.5 in /home/lse01/.local/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /home/lse01/.local/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.6.0)
# Requirement already satisfied: nvidia-cusparse==12.6.3.3.* in /home/lse01/.local/lib/python3.10/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.6.3.3)
# Requirement already satisfied: nvidia-cuda-cupti==13.0.85.* in /home/lse01/.local/lib/python3.10/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.8.0->ultralytics) (13.0.85)
# Requirement already satisfied: nvidia-cufft==12.0.0.61.* in /home/lse01/.local/lib/python3.10/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.0.0.61)
# Requirement already satisfied: nvidia-cusolver==12.0.4.66.* in /home/lse01/.local/lib/python3.10/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.0.4.66)
# Requirement already satisfied: nvidia-nvjitlink==13.0.88.* in /home/lse01/.local/lib/python3.10/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.8.0->ultralytics) (13.0.88)
# Requirement already satisfied: nvidia-nvtx==13.0.85.* in /home/lse01/.local/lib/python3.10/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.8.0->ultralytics) (13.0.85)
# Requirement already satisfied: nvidia-cufile==1.15.1.6.* in /home/lse01/.local/lib/python3.10/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.8.0->ultralytics) (1.15.1.6)
# Requirement already satisfied: nvidia-cublas==13.1.0.3.* in /home/lse01/.local/lib/python3.10/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.8.0->ultralytics) (13.1.0.3)
# Requirement already satisfied: nvidia-curand==10.4.0.35.* in /home/lse01/.local/lib/python3.10/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.8.0->ultralytics) (10.4.0.35)
# Requirement already satisfied: nvidia-cuda-nvrtc==13.0.88.* in /home/lse01/.local/lib/python3.10/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.8.0->ultralytics) (13.0.88)
# Requirement already satisfied: nvidia-cuda-runtime==13.0.96.* in /home/lse01/.local/lib/python3.10/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.8.0->ultralytics) (13.0.96)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /home/lse01/.local/lib/python3.10/site-packages (from cuda-bindings<14,>=13.0.3->torch>=1.8.0->ultralytics) (1.5.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/lse01/.local/lib/python3.10/site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/lse01/anaconda3/envs/yolo_env/lib/python3.10/site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=Dataset/data.yaml epochs=50 imgsz=640
# Out:
# /bin/bash: line 1: yolo: command not found
